# %%
import json
import requests
from bs4 import BeautifulSoup
import tkinter as tk
from tkinter import messagebox
from urllib.parse import urlparse, urljoin

def get_html_with_requests(url):
    parsed_url = urlparse(url)
    domain = parsed_url.netloc
 

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Encoding': 'gzip, deflate, br, zstd',
        'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,ru;q=0.6,es;q=0.5',
        'Cookie': 'ajs_anonymous_id=a03ba2e0-6658-4732-bca0-5c82a729610d; blueID=158f8c36-f884-4eeb-9dd2-41ddb36954f2; _fbp=fb.2.1719565497536.945089496421286543; _tt_enable_cookie=1; _ttp=yDIqAjbcrTkStMgfYKWUtQqV7qI; _scid=fe8f87fb-9164-4128-931f-6db8349a5902; _pin_unauth=dWlkPU16QmxZV015TVRndE16QmhOUzAwWmpRekxUZzROakF0Wm1VeFlUSTROREE1WXpJeg; _hjSessionUser_257734=eyJpZCI6IjZlYmVkNTczLWRlNDItNTljNy1iYjBkLWRjMzQxYzg1ZThkZiIsImNyZWF0ZWQiOjE3MTk1NjU0OTc1ODksImV4aXN0aW5nIjp0cnVlfQ==; __utmz=other; blueULC=blue; OptanonAlertBoxClosed=2024-06-28T10:07:39.896Z; _gac_UA-58792402-1=1.1719578340.CjwKCAjwvvmzBhA2EiwAtHVrbx5PuZ-Y6ZmDRgxSQAE3bhfdMkfQ6qO_h_InopnIh9t314DXR2UOdhoCJPMQAvD_BwE; origem=adwords; _rtbhouse_source_=AdWords; anonymousClient=true; _gcl_aw=GCL.1719608537.CjwKCAjwvvmzBhA2EiwAtHVrb7a4Gf1uUaMKzAcQ623DOKsXA0ynRueURMbfhKPxXrTvmq46s3W5ZBoCXV8QAvD_BwE; _gcl_gs=2.1.k1$i1719608535; _gid=GA1.3.1821486782.1720470235; _ScCbts=%5B%5D; petzCarrinho=true; JSESSIONID=9E56A4F6251336BC2EEC9640328DF1CE; _hjSession_257734=eyJpZCI6ImRmYjFhNzkxLTcwMDAtNDc5ZC1hZDA2LTE4NGYwZGMwOTQ3MSIsImMiOjE3MjA2MzEyODk1MzEsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; OptanonConsent=isGpcEnabled=0&datestamp=Wed+Jul+10+2024+14%3A33%3A28+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=202404.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=5d44d058-e0ca-4634-af6a-6ae970855f35&interactionCount=2&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0002%3A1%2CC0004%3A1&AwaitingReconsent=false&intType=1&geolocation=BR%3BRJ; AWSALB=hZab3iIPYsD0MIUknEJjbESldllV2XbXHeW6ABubXDqQC1w+fB9ShoCYGJIR2z0ndrcA5n/bdu5qP2SU+sm1uOdvT/LotUC6UCm2meSI5Mm4DIVUR9N7D5oqkEID; AWSALBCORS=hZab3iIPYsD0MIUknEJjbESldllV2XbXHeW6ABubXDqQC1w+fB9ShoCYGJIR2z0ndrcA5n/bdu5qP2SU+sm1uOdvT/LotUC6UCm2meSI5Mm4DIVUR9N7D5oqkEID; _ga_JB2JHD7FCJ=GS1.1.1720631306.23.1.1720632809.57.0.0; _ga=GA1.1.604824160.1719565115; _uetsid=006ad4a03d6811ef82e9db6f4cebf44a; _uetvid=7e097870352d11ef8996917c57f63d87; _scid_r=fe8f87fb-9164-4128-931f-6db8349a5902; _derived_epik=dj0yJnU9OVpXTXl0T0xlTmRISjQ3aGwtVFQ1SWZjVmJuT0JiaFkmbj1zc3Z6NkNFQXNmdnZHWmFDdEpIX093Jm09MSZ0PUFBQUFBR2FPeGVzJnJtPTEmcnQ9QUFBQUFHYU94ZXMmc3A9Mg; cto_bundle=; ab.storage.sessionId.8160f757-f57f-4d17-9cfb-44c82d5e8f64=%7B%22g%22%3A%221c387921-d350-d759-9bb8-04a9e46b2359%22%2C%22e%22%3A1720632840493%2C%22c%22%3A1720632809379%2C%22l%22%3A1720632810493%7D; RT="z=1&dm=www.petz.com.br&si=92ca62e5-ee3d-405f-ab43-07f1cffe3709&ss=lyg3fxm8&sl=6&tt=cia&obo=2&rl=1&ld=zeiw&r=ke1m2ztx&ul=zeix"',
        'Priority': 'u=0, i',
        'Referer': f"{domain}/marcas",
        'Sec-Ch-Ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
        'Sec-Ch-Ua-Mobile': '?0',
        'Sec-Ch-Ua-Platform': '"Windows"',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Erro ao obter HTML com requests: {response.status_code}")
        return None

def carregar_arquivo(arquivo):
    try:
        with open(arquivo, 'r', encoding='utf-8') as f:
            return json.load(f)
    except FileNotFoundError:
        return {"marcas": []}

def selecionar_marcas(marcas_desejadas, arquivo_saida):
    # Carregar o arquivo de saída, se existir
    marcas_selecionadas = carregar_arquivo(arquivo_saida)
    
    # Obter nomes das marcas já selecionadas
    nomes_marcas_selecionadas = {marca['name'] for marca in marcas_selecionadas['marcas']}
    
    # Filtrar e adicionar as novas marcas desejadas
    for marca in dados_marcas['subcategories']:
        if marca['name'] in marcas_desejadas and marca['name'] not in nomes_marcas_selecionadas:
            marcas_selecionadas['marcas'].append({
                "name": marca['name'],
                "link": marca['link'],
                "produtos": []
            })
    
    # Salvar as marcas selecionadas em um novo arquivo
    with open(arquivo_saida, 'w', encoding='utf-8') as f:
        json.dump(marcas_selecionadas, f, ensure_ascii=False, indent=4)
    
    return marcas_selecionadas['marcas']

def on_select():
    selected_items = listbox.curselection()
    selected_brands = [listbox.get(i) for i in selected_items]
    novas_marcas = selecionar_marcas(selected_brands, 'marcas_selecionadas.json')
    messagebox.showinfo("Informação", "Marcas selecionadas salvas com sucesso!")
    update_selected_listbox(novas_marcas)

def update_listbox(*args):
    search_term = entry_var.get().lower()
    listbox.delete(0, tk.END)
    for marca in dados_marcas['subcategories']:
        if search_term in marca['name'].lower():
            listbox.insert(tk.END, marca['name'])

def update_selected_listbox(marcas):
    selected_listbox.delete(0, tk.END)
    for marca in marcas:
        selected_listbox.insert(tk.END, marca['name'])

def delete_selected():
    selected_items = selected_listbox.curselection()
    if not selected_items:
        return
    
    marcas_selecionadas = carregar_arquivo('marcas_selecionadas.json')
    nomes_marcas_selecionadas = {marca['name'] for marca in marcas_selecionadas['marcas']}
    
    for i in selected_items[::-1]:  # Reverter a lista para evitar problemas de índice ao deletar
        marca_name = selected_listbox.get(i)
        if marca_name in nomes_marcas_selecionadas:
            marcas_selecionadas['marcas'] = [marca for marca in marcas_selecionadas['marcas'] if marca['name'] != marca_name]
            selected_listbox.delete(i)
    
    with open('marcas_selecionadas.json', 'w', encoding='utf-8') as f:
        json.dump(marcas_selecionadas, f, ensure_ascii=False, indent=4)
    messagebox.showinfo("Informação", "Marcas deletadas com sucesso!")

def obter_marcas_do_site(url):
    html_content = get_html_with_requests(url)
    if not html_content:
        return {"subcategories": []}
    
    soup = BeautifulSoup(html_content, 'html.parser')
    marcas = []
    for li in soup.select('div.glossario-resultados ul li.marcas'):
        nome = li.find('p').text.strip()
        link = li.find('a')['href']
        # Converter link relativo para absoluto
        link_absoluto = urljoin(url, link)
        marcas.append({"name": nome, "link": link_absoluto})
    print(f"Marcas obtidas: {marcas}")
    return {"subcategories": marcas}

def carregar_marcas():
    url = url_entry.get()
    print(f"URL fornecida: {url}")
    global dados_marcas
    dados_marcas = obter_marcas_do_site(url)
    update_listbox()

# Criar a interface gráfica
root = tk.Tk()
root.title("Seleção de Marcas")

label_url = tk.Label(root, text="Digite a URL do site:")
label_url.pack(pady=10)

url_entry = tk.Entry(root, width=50)
url_entry.pack(pady=10)

button_carregar = tk.Button(root, text="Carregar Marcas", command=carregar_marcas)
button_carregar.pack(pady=10)

label = tk.Label(root, text="Selecione as marcas desejadas:")
label.pack(pady=10)

entry_var = tk.StringVar()
entry_var.trace("w", update_listbox)
entry = tk.Entry(root, textvariable=entry_var, width=50)
entry.pack(pady=10)

listbox = tk.Listbox(root, selectmode=tk.MULTIPLE, width=50, height=20)
listbox.pack(pady=10)

button = tk.Button(root, text="Salvar Seleção", command=on_select)
button.pack(pady=10)

label_selected = tk.Label(root, text="Marcas Selecionadas:")
label_selected.pack(pady=10)

selected_listbox = tk.Listbox(root, selectmode=tk.MULTIPLE, width=50, height=10)
selected_listbox.pack(pady=10)

button_delete = tk.Button(root, text="Deletar Selecionadas", command=delete_selected)
button_delete.pack(pady=10)

# Carregar e exibir as marcas já selecionadas
marcas_selecionadas = carregar_arquivo('marcas_selecionadas.json')
update_selected_listbox(marcas_selecionadas['marcas'])

root.mainloop()
